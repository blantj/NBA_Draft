# %% [markdown]
# # Read and clean excel files with draftee NBA and combine stats

# %% [markdown]
# Import necessary packages

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import time
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %% [markdown]
# Read csv with draft combine data to df and drop empty column

# %%
combine_df = pd.read_csv('nba_draft_combine.csv')
combine_df.drop(columns='Unnamed: 0',inplace=True)
combine_df.head()
# Out:
#               Player  Year  Draft pick  Height (No Shoes)  \
# 0      Blake Griffin  2009         1.0              80.50
# 1  Terrence Williams  2009        11.0              77.00
# 2   Gerald Henderson  2009        12.0              76.00
# 3   Tyler Hansbrough  2009        13.0              80.25
# 4         Earl Clark  2009        14.0              80.50
#
#    Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                82.00     83.25           105.0            35.5
# 1                78.25     81.00           103.5            37.0
# 2                77.00     82.25           102.5            35.0
# 3                81.50     83.50           106.0            34.0
# 4                82.25     86.50           109.5            33.0
#
#    Vertical (Max Reach)  Vertical (No Step)  Vertical (No Step Reach)  Weight  \
# 0                 140.5                32.0                     137.0   248.0
# 1                 140.5                30.5                     134.0   213.0
# 2                 137.5                31.5                     134.0   215.0
# 3                 140.0                27.5                     133.5   234.0
# 4                 142.5                28.5                     138.0   228.0
#
#    Body Fat  Hand (Length)  Hand (Width)  Bench  Agility  Sprint
# 0       8.2            NaN           NaN   22.0    10.95    3.28
# 1       5.1            NaN           NaN    9.0    11.15    3.18
# 2       4.4            NaN           NaN    8.0    11.17    3.14
# 3       8.5            NaN           NaN   18.0    11.12    3.27
# 4       5.2            NaN           NaN    5.0    11.17    3.35

# %% [markdown]
# Change name of misnamed player in draft combine dataframe

# %%
combine_df.loc[combine_df[combine_df['Player']=='JaJuan Johnson (Purdue)'].index,'Player'] = 'JaJuan Johnson'
combine_df[combine_df['Player']=='JaJuan Johnson']
# Out:
#              Player  Year  Draft pick  Height (No Shoes)  Height (With Shoes)  \
# 113  JaJuan Johnson  2011        27.0               81.0                 82.0
#
#      Wingspan  Standing reach  Vertical (Max)  Vertical (Max Reach)  \
# 113      86.0           107.5            38.0                 145.5
#
#      Vertical (No Step)  Vertical (No Step Reach)  Weight  Body Fat  \
# 113                33.5                     141.0   220.0       7.5
#
#      Hand (Length)  Hand (Width)  Bench  Agility  Sprint
# 113            9.0          10.0   15.0    11.21    3.14

# %% [markdown]
# Read csvs with each draft class' nba stats to dfs and concatenate all classes into a single df

# %%
nba_stats_2009 = pd.read_csv('nba_stats_2009.csv')
nba_stats_2009.drop(60,inplace=True)
nba_stats_2009['Year']=2009
nba_stats_2010 = pd.read_csv('nba_stats_2010.csv')
nba_stats_2010.drop(60,inplace=True)
nba_stats_2010['Year']=2010
nba_stats_2011 = pd.read_csv('nba_stats_2011.csv')
nba_stats_2011.drop(60,inplace=True)
nba_stats_2011['Year']=2011
nba_stats_2012 = pd.read_csv('nba_stats_2012.csv')
nba_stats_2012.drop(60,inplace=True)
nba_stats_2012['Year']=2012
nba_stats_2013 = pd.read_csv('nba_stats_2013.csv')
nba_stats_2013.drop(60,inplace=True)
nba_stats_2013['Year']=2013
nba_stats_2014 = pd.read_csv('nba_stats_2014.csv')
nba_stats_2014.drop(60,inplace=True)
nba_stats_2014['Year']=2014
nba_stats_2015 = pd.read_csv('nba_stats_2015.csv')
nba_stats_2015.drop(60,inplace=True)
nba_stats_2015['Year']=2015
nba_stats_2016 = pd.read_csv('nba_stats_2016.csv')
nba_stats_2016.drop(60,inplace=True)
nba_stats_2016['Year']=2016
nba_stats_2017 = pd.read_csv('nba_stats_2017.csv')
nba_stats_2017.drop(60,inplace=True)
nba_stats_2017['Year']=2017
nba_df = pd.concat([nba_stats_2009,nba_stats_2010,nba_stats_2011,nba_stats_2012,nba_stats_2013,nba_stats_2014,
                   nba_stats_2015,nba_stats_2016,nba_stats_2017],axis=0)
nba_df.drop('Rk',axis=1,inplace=True)
print(nba_df.columns)
nba_df.head()
# Out:
# Index(['Pk', 'Tm', 'Player', 'College', 'Yrs', 'G', 'MP', 'PTS', 'TRB', 'AST',
#        'FG%', '3P%', 'FT%', 'MP.1', 'PTS.1', 'TRB.1', 'AST.1', 'WS', 'WS/48',
#        'BPM', 'VORP', 'Year'],
#       dtype='object')
#     Pk   Tm           Player        College   Yrs      G       MP      PTS  \
# 0  1.0  LAC    Blake Griffin       Oklahoma  10.0  622.0  21671.0  13479.0
# 1  2.0  MEM  Hasheem Thabeet          UConn   5.0  224.0   2357.0    483.0
# 2  3.0  OKC     James Harden  Arizona State  11.0  826.0  28347.0  20723.0
# 3  4.0  SAC     Tyreke Evans        Memphis  10.0  594.0  18242.0   9347.0
# 4  5.0  MIN      Ricky Rubio            NaN   9.0  555.0  17172.0   6269.0
#
#       TRB     AST  ...    FT%  MP.1  PTS.1  TRB.1  AST.1     WS  WS/48  BPM  \
# 0  5501.0  2749.0  ...  0.694  34.8   21.7    8.8    4.4   75.2  0.167  3.8
# 1   595.0    27.0  ...  0.578  10.5    2.2    2.7    0.1    4.8  0.099 -2.7
# 2  4388.0  5193.0  ...  0.858  34.3   25.1    5.3    6.3  133.3  0.226  6.9
# 3  2720.0  2852.0  ...  0.757  30.7   15.7    4.6    4.8   28.4  0.075  0.8
# 4  2357.0  4324.0  ...  0.840  30.9   11.3    4.2    7.8   36.4  0.102  0.9
#
#    VORP  Year
# 0  31.9  2009
# 1  -0.4  2009
# 2  63.6  2009
# 3  13.1  2009
# 4  12.6  2009
#
# [5 rows x 22 columns]

# %% [markdown]
# Define function for determining the y variable class for each datapoint and use to create y variable column, Rotation.

# %%
def rotation_player(row):
    rotation_player = 0
    if row['PTS.1']>9 and row['G']>100:
        rotation_player = 1
    return rotation_player
        

nba_df['Rotation'] = nba_df.apply(rotation_player, axis=1)
nba_df.head()
# Out:
#     Pk   Tm           Player        College   Yrs      G       MP      PTS  \
# 0  1.0  LAC    Blake Griffin       Oklahoma  10.0  622.0  21671.0  13479.0
# 1  2.0  MEM  Hasheem Thabeet          UConn   5.0  224.0   2357.0    483.0
# 2  3.0  OKC     James Harden  Arizona State  11.0  826.0  28347.0  20723.0
# 3  4.0  SAC     Tyreke Evans        Memphis  10.0  594.0  18242.0   9347.0
# 4  5.0  MIN      Ricky Rubio            NaN   9.0  555.0  17172.0   6269.0
#
#       TRB     AST  ...  MP.1  PTS.1  TRB.1  AST.1     WS  WS/48  BPM  VORP  \
# 0  5501.0  2749.0  ...  34.8   21.7    8.8    4.4   75.2  0.167  3.8  31.9
# 1   595.0    27.0  ...  10.5    2.2    2.7    0.1    4.8  0.099 -2.7  -0.4
# 2  4388.0  5193.0  ...  34.3   25.1    5.3    6.3  133.3  0.226  6.9  63.6
# 3  2720.0  2852.0  ...  30.7   15.7    4.6    4.8   28.4  0.075  0.8  13.1
# 4  2357.0  4324.0  ...  30.9   11.3    4.2    7.8   36.4  0.102  0.9  12.6
#
#    Year  Rotation
# 0  2009         1
# 1  2009         0
# 2  2009         1
# 3  2009         1
# 4  2009         1
#
# [5 rows x 23 columns]

# %% [markdown]
# # Scrape draftee college stats and clean resulting df

# %% [markdown]
# Generate list of urls to be scraped from player list and manually update urls that deviate from main format

# %%
players = list(combine_df[combine_df['Draft pick']>0]['Player'].values)
urls = []
for player in players:
    player = player.replace(' ','-').lower()
    player = player.replace('.','')
    url = 'https://www.sports-reference.com/cbb/players/{}-1.html'.format(player)
    urls.append(url)
urls = ['https://www.sports-reference.com/cbb/players/glen-rice-jr-1.html' if x == 'https://www.sports-reference.com/cbb/players/glen-rice-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/glenn-robinson-2.html' if x == 'https://www.sports-reference.com/cbb/players/glenn-robinson-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/gerald-henderson-2.html' if x == 'https://www.sports-reference.com/cbb/players/gerald-henderson-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/larry-nance-2.html' if x == 'https://www.sports-reference.com/cbb/players/larry-nance-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/jeffery-taylor-1.html'if x == 'https://www.sports-reference.com/cbb/players/jeff-taylor-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/bj-mullens-1.html' if x == 'https://www.sports-reference.com/cbb/players/byron-mullens-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/etwaun-moore-1.html' if x == "https://www.sports-reference.com/cbb/players/e'twaun-moore-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/maurice-harkless-1.html' if x == 'https://www.sports-reference.com/cbb/players/moe-harkless-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/bernard-james--1.html' if x == 'https://www.sports-reference.com/cbb/players/bernard-james-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/thomas-robinson-2.html' if x == 'https://www.sports-reference.com/cbb/players/thomas-robinson-1.html' else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/kyle-oquinn-1.html' if x == "https://www.sports-reference.com/cbb/players/kyle-o'quinn-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/ray-mccallum-2.html' if x == "https://www.sports-reference.com/cbb/players/ray-mccallum-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/kyle-anderson-3.html' if x == "https://www.sports-reference.com/cbb/players/kyle-anderson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/johnny-obryant-1.html' if x == "https://www.sports-reference.com/cbb/players/johnny-o'bryant-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/roy-devyn-marble-1.html' if x == "https://www.sports-reference.com/cbb/players/devyn-marble-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/dangelo-russell-1.html' if x == "https://www.sports-reference.com/cbb/players/d'angelo-russell-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/stephen-zimmermanjr-1.html' if x == "https://www.sports-reference.com/cbb/players/stephen-zimmerman-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/kahlil-felder-1.html' if x == "https://www.sports-reference.com/cbb/players/kay-felder-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/edrice-adebayo-1.html' if x == "https://www.sports-reference.com/cbb/players/bam-adebayo-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/deaaron-fox-1.html' if x == "https://www.sports-reference.com/cbb/players/de'aaron-fox-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/reggie-bullock-2.html' if x == "https://www.sports-reference.com/cbb/players/reggie-bullock-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/tony-mitchell-4.html' if x == "https://www.sports-reference.com/cbb/players/tony-mitchell-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/derrick-williams-2.html' if x == "https://www.sports-reference.com/cbb/players/derrick-williams-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/ryan-kelly-3.html' if x == "https://www.sports-reference.com/cbb/players/ryan-kelly-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/justin-jackson-4.html' if x == "https://www.sports-reference.com/cbb/players/justin-jackson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/frank-jackson-2.html' if x == "https://www.sports-reference.com/cbb/players/frank-jackson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/james-johnson-2.html' if x == "https://www.sports-reference.com/cbb/players/james-johnson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/wes-johnson-1.html' if x == "https://www.sports-reference.com/cbb/players/wesley-johnson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/jordan-hamilton-2.html' if x == "https://www.sports-reference.com/cbb/players/jordan-hamilton-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/anthony-davis-5.html' if x == "https://www.sports-reference.com/cbb/players/anthony-davis-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/aaron-white-3.html' if x == "https://www.sports-reference.com/cbb/players/aaron-white-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/demetrius-jackson-2.html' if x == "https://www.sports-reference.com/cbb/players/demetrius-jackson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/mike-scott-4.html' if x == "https://www.sports-reference.com/cbb/players/mike-scott-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/james-anderson-3.html' if x == "https://www.sports-reference.com/cbb/players/james-anderson-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/anthony-brown-5.html' if x == "https://www.sports-reference.com/cbb/players/anthony-brown-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/joe-harris--1.html' if x == "https://www.sports-reference.com/cbb/players/joe-harris-1.html" else x for x in urls]
urls = ['https://www.sports-reference.com/cbb/players/jared-cunningham-2.html' if x == "https://www.sports-reference.com/cbb/players/jared-cunningham-1.html" else x for x in urls]

urls
# Out:
# ['https://www.sports-reference.com/cbb/players/blake-griffin-1.html',
#  'https://www.sports-reference.com/cbb/players/terrence-williams-1.html',
#  'https://www.sports-reference.com/cbb/players/gerald-henderson-2.html',
#  'https://www.sports-reference.com/cbb/players/tyler-hansbrough-1.html',
#  'https://www.sports-reference.com/cbb/players/earl-clark-1.html',
#  'https://www.sports-reference.com/cbb/players/austin-daye-1.html',
#  'https://www.sports-reference.com/cbb/players/james-johnson-2.html',
#  'https://www.sports-reference.com/cbb/players/jrue-holiday-1.html',
#  'https://www.sports-reference.com/cbb/players/ty-lawson-1.html',
#  'https://www.sports-reference.com/cbb/players/jeff-teague-1.html',
#  'https://www.sports-reference.com/cbb/players/hasheem-thabeet-1.html',
#  'https://www.sports-reference.com/cbb/players/eric-maynor-1.html',
#  'https://www.sports-reference.com/cbb/players/darren-collison-1.html',
#  'https://www.sports-reference.com/cbb/players/omri-casspi-1.html',
#  'https://www.sports-reference.com/cbb/players/bj-mullens-1.html',
#  'https://www.sports-reference.com/cbb/players/damion-james-1.html',
#  'https://www.sports-reference.com/cbb/players/rodrigue-beaubois-1.html',
#  'https://www.sports-reference.com/cbb/players/taj-gibson-1.html',
#  'https://www.sports-reference.com/cbb/players/demarre-carroll-1.html',
#  'https://www.sports-reference.com/cbb/players/greivis-vasquez-1.html',
#  'https://www.sports-reference.com/cbb/players/wayne-ellington-1.html',
#  'https://www.sports-reference.com/cbb/players/toney-douglas-1.html',
#  'https://www.sports-reference.com/cbb/players/james-harden-1.html',
#  'https://www.sports-reference.com/cbb/players/jeff-pendergraph-1.html',
#  'https://www.sports-reference.com/cbb/players/jermaine-taylor-1.html',
#  'https://www.sports-reference.com/cbb/players/dante-cunningham-1.html',
#  'https://www.sports-reference.com/cbb/players/dajuan-summers-1.html',
#  'https://www.sports-reference.com/cbb/players/sam-young-1.html',
#  'https://www.sports-reference.com/cbb/players/dejuan-blair-1.html',
#  'https://www.sports-reference.com/cbb/players/tyreke-evans-1.html',
#  'https://www.sports-reference.com/cbb/players/derrick-brown-1.html',
#  'https://www.sports-reference.com/cbb/players/jodie-meeks-1.html',
#  'https://www.sports-reference.com/cbb/players/marcus-thornton-1.html',
#  'https://www.sports-reference.com/cbb/players/chase-budinger-1.html',
#  'https://www.sports-reference.com/cbb/players/danny-green-1.html',
#  'https://www.sports-reference.com/cbb/players/gani-lawal-1.html',
#  'https://www.sports-reference.com/cbb/players/jack-mcclinton-1.html',
#  'https://www.sports-reference.com/cbb/players/aj-price-1.html',
#  'https://www.sports-reference.com/cbb/players/luke-harangody-1.html',
#  'https://www.sports-reference.com/cbb/players/patrick-mills-1.html',
#  'https://www.sports-reference.com/cbb/players/jonny-flynn-1.html',
#  'https://www.sports-reference.com/cbb/players/stephen-curry-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-hill-1.html',
#  'https://www.sports-reference.com/cbb/players/demar-derozan-1.html',
#  'https://www.sports-reference.com/cbb/players/john-wall-1.html',
#  'https://www.sports-reference.com/cbb/players/paul-george-1.html',
#  'https://www.sports-reference.com/cbb/players/cole-aldrich-1.html',
#  'https://www.sports-reference.com/cbb/players/xavier-henry-1.html',
#  'https://www.sports-reference.com/cbb/players/ed-davis-1.html',
#  'https://www.sports-reference.com/cbb/players/patrick-patterson-1.html',
#  'https://www.sports-reference.com/cbb/players/larry-sanders-1.html',
#  'https://www.sports-reference.com/cbb/players/luke-babbitt-1.html',
#  'https://www.sports-reference.com/cbb/players/eric-bledsoe-1.html',
#  'https://www.sports-reference.com/cbb/players/avery-bradley-1.html',
#  'https://www.sports-reference.com/cbb/players/evan-turner-1.html',
#  'https://www.sports-reference.com/cbb/players/james-anderson-3.html',
#  'https://www.sports-reference.com/cbb/players/craig-brackins-1.html',
#  'https://www.sports-reference.com/cbb/players/trevor-booker-1.html',
#  'https://www.sports-reference.com/cbb/players/dominique-jones-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-crawford-1.html',
#  'https://www.sports-reference.com/cbb/players/daniel-orton-1.html',
#  'https://www.sports-reference.com/cbb/players/derrick-favors-1.html',
#  'https://www.sports-reference.com/cbb/players/lazar-hayward-1.html',
#  'https://www.sports-reference.com/cbb/players/dexter-pittman-1.html',
#  'https://www.sports-reference.com/cbb/players/hassan-whiteside-1.html',
#  'https://www.sports-reference.com/cbb/players/armon-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/terrico-white-1.html',
#  'https://www.sports-reference.com/cbb/players/darington-hobson-1.html',
#  'https://www.sports-reference.com/cbb/players/andy-rautins-1.html',
#  'https://www.sports-reference.com/cbb/players/wes-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/lance-stephenson-1.html',
#  'https://www.sports-reference.com/cbb/players/jarvis-varnado-1.html',
#  'https://www.sports-reference.com/cbb/players/devin-ebanks-1.html',
#  'https://www.sports-reference.com/cbb/players/jerome-jordan-1.html',
#  'https://www.sports-reference.com/cbb/players/tiny-gallon-1.html',
#  'https://www.sports-reference.com/cbb/players/ryan-richards-1.html',
#  'https://www.sports-reference.com/cbb/players/demarcus-cousins-1.html',
#  'https://www.sports-reference.com/cbb/players/solomon-alabi-1.html',
#  'https://www.sports-reference.com/cbb/players/willie-warren-1.html',
#  'https://www.sports-reference.com/cbb/players/derrick-caracter-1.html',
#  'https://www.sports-reference.com/cbb/players/stanley-robinson-1.html',
#  'https://www.sports-reference.com/cbb/players/ekpe-udoh-1.html',
#  'https://www.sports-reference.com/cbb/players/greg-monroe-1.html',
#  'https://www.sports-reference.com/cbb/players/al-farouq-aminu-1.html',
#  'https://www.sports-reference.com/cbb/players/gordon-hayward-1.html',
#  'https://www.sports-reference.com/cbb/players/jimmer-fredette-1.html',
#  'https://www.sports-reference.com/cbb/players/klay-thompson-1.html',
#  'https://www.sports-reference.com/cbb/players/alec-burks-1.html',
#  'https://www.sports-reference.com/cbb/players/markieff-morris-1.html',
#  'https://www.sports-reference.com/cbb/players/marcus-morris-1.html',
#  'https://www.sports-reference.com/cbb/players/kawhi-leonard-1.html',
#  'https://www.sports-reference.com/cbb/players/nikola-vucevic-1.html',
#  'https://www.sports-reference.com/cbb/players/iman-shumpert-1.html',
#  'https://www.sports-reference.com/cbb/players/chris-singleton-1.html',
#  'https://www.sports-reference.com/cbb/players/tobias-harris-1.html',
#  'https://www.sports-reference.com/cbb/players/derrick-williams-2.html',
#  'https://www.sports-reference.com/cbb/players/nolan-smith-1.html',
#  'https://www.sports-reference.com/cbb/players/kenneth-faried-1.html',
#  'https://www.sports-reference.com/cbb/players/marshon-brooks-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-hamilton-2.html',
#  'https://www.sports-reference.com/cbb/players/jajuan-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/norris-cole-1.html',
#  'https://www.sports-reference.com/cbb/players/cory-joseph-1.html',
#  'https://www.sports-reference.com/cbb/players/enes-kanter-1.html',
#  'https://www.sports-reference.com/cbb/players/jimmy-butler-1.html',
#  'https://www.sports-reference.com/cbb/players/justin-harper-1.html',
#  'https://www.sports-reference.com/cbb/players/kyle-singler-1.html',
#  'https://www.sports-reference.com/cbb/players/shelvin-mack-1.html',
#  'https://www.sports-reference.com/cbb/players/tyler-honeycutt-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-williams-1.html',
#  'https://www.sports-reference.com/cbb/players/trey-thompkins-1.html',
#  'https://www.sports-reference.com/cbb/players/chandler-parsons-1.html',
#  'https://www.sports-reference.com/cbb/players/jeremy-tyler-1.html',
#  'https://www.sports-reference.com/cbb/players/tristan-thompson-1.html',
#  'https://www.sports-reference.com/cbb/players/jon-leuer-1.html',
#  'https://www.sports-reference.com/cbb/players/darius-morris-1.html',
#  'https://www.sports-reference.com/cbb/players/malcolm-lee-1.html',
#  'https://www.sports-reference.com/cbb/players/charles-jenkins-1.html',
#  'https://www.sports-reference.com/cbb/players/andrew-goudelock-1.html',
#  'https://www.sports-reference.com/cbb/players/travis-leslie-1.html',
#  'https://www.sports-reference.com/cbb/players/keith-benson-1.html',
#  'https://www.sports-reference.com/cbb/players/josh-selby-1.html',
#  'https://www.sports-reference.com/cbb/players/jon-diebler-1.html',
#  'https://www.sports-reference.com/cbb/players/deandre-liggins-1.html',
#  'https://www.sports-reference.com/cbb/players/etwaun-moore-1.html',
#  'https://www.sports-reference.com/cbb/players/isaiah-thomas-1.html',
#  'https://www.sports-reference.com/cbb/players/brandon-knight-1.html',
#  'https://www.sports-reference.com/cbb/players/kemba-walker-1.html',
#  'https://www.sports-reference.com/cbb/players/anthony-davis-5.html',
#  'https://www.sports-reference.com/cbb/players/austin-rivers-1.html',
#  'https://www.sports-reference.com/cbb/players/meyers-leonard-1.html',
#  'https://www.sports-reference.com/cbb/players/jeremy-lamb-1.html',
#  'https://www.sports-reference.com/cbb/players/kendall-marshall-1.html',
#  'https://www.sports-reference.com/cbb/players/john-henson-1.html',
#  'https://www.sports-reference.com/cbb/players/maurice-harkless-1.html',
#  'https://www.sports-reference.com/cbb/players/royce-white-1.html',
#  'https://www.sports-reference.com/cbb/players/tyler-zeller-1.html',
#  'https://www.sports-reference.com/cbb/players/terrence-jones-1.html',
#  'https://www.sports-reference.com/cbb/players/andrew-nicholson-1.html',
#  'https://www.sports-reference.com/cbb/players/michael-kidd-gilchrist-1.html',
#  'https://www.sports-reference.com/cbb/players/jared-sullinger-1.html',
#  'https://www.sports-reference.com/cbb/players/fab-melo-1.html',
#  'https://www.sports-reference.com/cbb/players/john-jenkins-1.html',
#  'https://www.sports-reference.com/cbb/players/jared-cunningham-2.html',
#  'https://www.sports-reference.com/cbb/players/tony-wroten-1.html',
#  'https://www.sports-reference.com/cbb/players/miles-plumlee-1.html',
#  'https://www.sports-reference.com/cbb/players/arnett-moultrie-1.html',
#  'https://www.sports-reference.com/cbb/players/perry-jones-1.html',
#  'https://www.sports-reference.com/cbb/players/marquis-teague-1.html',
#  'https://www.sports-reference.com/cbb/players/bradley-beal-1.html',
#  'https://www.sports-reference.com/cbb/players/festus-ezeli-1.html',
#  'https://www.sports-reference.com/cbb/players/jeffery-taylor-1.html',
#  'https://www.sports-reference.com/cbb/players/tomas-satoransky-1.html',
#  'https://www.sports-reference.com/cbb/players/bernard-james--1.html',
#  'https://www.sports-reference.com/cbb/players/jae-crowder-1.html',
#  'https://www.sports-reference.com/cbb/players/draymond-green-1.html',
#  'https://www.sports-reference.com/cbb/players/orlando-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/quincy-acy-1.html',
#  'https://www.sports-reference.com/cbb/players/quincy-miller-1.html',
#  'https://www.sports-reference.com/cbb/players/khris-middleton-1.html',
#  'https://www.sports-reference.com/cbb/players/dion-waiters-1.html',
#  'https://www.sports-reference.com/cbb/players/will-barton-1.html',
#  'https://www.sports-reference.com/cbb/players/tyshawn-taylor-1.html',
#  'https://www.sports-reference.com/cbb/players/doron-lamb-1.html',
#  'https://www.sports-reference.com/cbb/players/mike-scott-4.html',
#  'https://www.sports-reference.com/cbb/players/kim-english-1.html',
#  'https://www.sports-reference.com/cbb/players/darius-miller-1.html',
#  'https://www.sports-reference.com/cbb/players/kevin-murphy-1.html',
#  'https://www.sports-reference.com/cbb/players/kyle-oquinn-1.html',
#  'https://www.sports-reference.com/cbb/players/thomas-robinson-2.html',
#  'https://www.sports-reference.com/cbb/players/kris-joseph-1.html',
#  'https://www.sports-reference.com/cbb/players/darius-johnson-odom-1.html',
#  'https://www.sports-reference.com/cbb/players/robbie-hummel-1.html',
#  'https://www.sports-reference.com/cbb/players/marcus-denmon-1.html',
#  'https://www.sports-reference.com/cbb/players/damian-lillard-1.html',
#  'https://www.sports-reference.com/cbb/players/harrison-barnes-1.html',
#  'https://www.sports-reference.com/cbb/players/terrence-ross-1.html',
#  'https://www.sports-reference.com/cbb/players/andre-drummond-1.html',
#  'https://www.sports-reference.com/cbb/players/cj-mccollum-1.html',
#  'https://www.sports-reference.com/cbb/players/michael-carter-williams-1.html',
#  'https://www.sports-reference.com/cbb/players/steven-adams-1.html',
#  'https://www.sports-reference.com/cbb/players/kelly-olynyk-1.html',
#  'https://www.sports-reference.com/cbb/players/shabazz-muhammad-1.html',
#  'https://www.sports-reference.com/cbb/players/dennis-schroeder-1.html',
#  'https://www.sports-reference.com/cbb/players/shane-larkin-1.html',
#  'https://www.sports-reference.com/cbb/players/victor-oladipo-1.html',
#  'https://www.sports-reference.com/cbb/players/tony-snell-1.html',
#  'https://www.sports-reference.com/cbb/players/gorgui-dieng-1.html',
#  'https://www.sports-reference.com/cbb/players/mason-plumlee-1.html',
#  'https://www.sports-reference.com/cbb/players/solomon-hill-1.html',
#  'https://www.sports-reference.com/cbb/players/tim-hardaway-jr-1.html',
#  'https://www.sports-reference.com/cbb/players/reggie-bullock-2.html',
#  'https://www.sports-reference.com/cbb/players/andre-roberson-1.html',
#  'https://www.sports-reference.com/cbb/players/rudy-gobert-1.html',
#  'https://www.sports-reference.com/cbb/players/archie-goodwin-1.html',
#  'https://www.sports-reference.com/cbb/players/otto-porter-1.html',
#  'https://www.sports-reference.com/cbb/players/allen-crabbe-1.html',
#  'https://www.sports-reference.com/cbb/players/carrick-felix-1.html',
#  'https://www.sports-reference.com/cbb/players/isaiah-canaan-1.html',
#  'https://www.sports-reference.com/cbb/players/glen-rice-jr-1.html',
#  'https://www.sports-reference.com/cbb/players/ray-mccallum-2.html',
#  'https://www.sports-reference.com/cbb/players/tony-mitchell-4.html',
#  'https://www.sports-reference.com/cbb/players/nate-wolters-1.html',
#  'https://www.sports-reference.com/cbb/players/jeff-withey-1.html',
#  'https://www.sports-reference.com/cbb/players/cody-zeller-1.html',
#  'https://www.sports-reference.com/cbb/players/grant-jerrett-1.html',
#  'https://www.sports-reference.com/cbb/players/jamaal-franklin-1.html',
#  'https://www.sports-reference.com/cbb/players/pierre-jackson-1.html',
#  'https://www.sports-reference.com/cbb/players/ricky-ledo-1.html',
#  'https://www.sports-reference.com/cbb/players/mike-muscala-1.html',
#  'https://www.sports-reference.com/cbb/players/erick-green-1.html',
#  'https://www.sports-reference.com/cbb/players/ryan-kelly-3.html',
#  'https://www.sports-reference.com/cbb/players/erik-murphy-1.html',
#  'https://www.sports-reference.com/cbb/players/james-ennis-1.html',
#  'https://www.sports-reference.com/cbb/players/lorenzo-brown-1.html',
#  'https://www.sports-reference.com/cbb/players/colton-iverson-1.html',
#  'https://www.sports-reference.com/cbb/players/peyton-siva-1.html',
#  'https://www.sports-reference.com/cbb/players/deshaun-thomas-1.html',
#  'https://www.sports-reference.com/cbb/players/nerlens-noel-1.html',
#  'https://www.sports-reference.com/cbb/players/ben-mclemore-1.html',
#  'https://www.sports-reference.com/cbb/players/kentavious-caldwell-pope-1.html',
#  'https://www.sports-reference.com/cbb/players/trey-burke-1.html',
#  'https://www.sports-reference.com/cbb/players/elfrid-payton-1.html',
#  'https://www.sports-reference.com/cbb/players/doug-mcdermott-1.html',
#  'https://www.sports-reference.com/cbb/players/zach-lavine-1.html',
#  'https://www.sports-reference.com/cbb/players/tj-warren-1.html',
#  'https://www.sports-reference.com/cbb/players/adreian-payne-1.html',
#  'https://www.sports-reference.com/cbb/players/james-young-1.html',
#  'https://www.sports-reference.com/cbb/players/tyler-ennis-1.html',
#  'https://www.sports-reference.com/cbb/players/gary-harris-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-adams-1.html',
#  'https://www.sports-reference.com/cbb/players/rodney-hood-1.html',
#  'https://www.sports-reference.com/cbb/players/shabazz-napier-1.html',
#  'https://www.sports-reference.com/cbb/players/pj-hairston-1.html',
#  'https://www.sports-reference.com/cbb/players/cj-wilcox-1.html',
#  'https://www.sports-reference.com/cbb/players/kyle-anderson-3.html',
#  'https://www.sports-reference.com/cbb/players/kj-mcdaniels-1.html',
#  'https://www.sports-reference.com/cbb/players/joe-harris--1.html',
#  'https://www.sports-reference.com/cbb/players/cleanthony-early-1.html',
#  'https://www.sports-reference.com/cbb/players/jarnell-stokes-1.html',
#  'https://www.sports-reference.com/cbb/players/johnny-obryant-1.html',
#  'https://www.sports-reference.com/cbb/players/deandre-daniels-1.html',
#  'https://www.sports-reference.com/cbb/players/spencer-dinwiddie-1.html',
#  'https://www.sports-reference.com/cbb/players/jerami-grant-1.html',
#  'https://www.sports-reference.com/cbb/players/aaron-gordon-1.html',
#  'https://www.sports-reference.com/cbb/players/glenn-robinson-2.html',
#  'https://www.sports-reference.com/cbb/players/nick-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/markel-brown-1.html',
#  'https://www.sports-reference.com/cbb/players/dwight-powell-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-clarkson-1.html',
#  'https://www.sports-reference.com/cbb/players/russ-smith-1.html',
#  'https://www.sports-reference.com/cbb/players/lamar-patterson-1.html',
#  'https://www.sports-reference.com/cbb/players/cameron-bairstow-1.html',
#  'https://www.sports-reference.com/cbb/players/dante-exum-1.html',
#  'https://www.sports-reference.com/cbb/players/alec-brown-1.html',
#  'https://www.sports-reference.com/cbb/players/thanasis-antetokounmpo-1.html',
#  'https://www.sports-reference.com/cbb/players/semaj-christon-1.html',
#  'https://www.sports-reference.com/cbb/players/roy-devyn-marble-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-mcrae-1.html',
#  'https://www.sports-reference.com/cbb/players/xavier-thames-1.html',
#  'https://www.sports-reference.com/cbb/players/marcus-smart-1.html',
#  'https://www.sports-reference.com/cbb/players/cory-jefferson-1.html',
#  'https://www.sports-reference.com/cbb/players/julius-randle-1.html',
#  'https://www.sports-reference.com/cbb/players/nik-stauskas-1.html',
#  'https://www.sports-reference.com/cbb/players/noah-vonleh-1.html',
#  'https://www.sports-reference.com/cbb/players/justise-winslow-1.html',
#  'https://www.sports-reference.com/cbb/players/myles-turner-1.html',
#  'https://www.sports-reference.com/cbb/players/trey-lyles-1.html',
#  'https://www.sports-reference.com/cbb/players/devin-booker-1.html',
#  'https://www.sports-reference.com/cbb/players/cameron-payne-1.html',
#  'https://www.sports-reference.com/cbb/players/kelly-oubre-1.html',
#  'https://www.sports-reference.com/cbb/players/terry-rozier-1.html',
#  'https://www.sports-reference.com/cbb/players/rashad-vaughn-1.html',
#  'https://www.sports-reference.com/cbb/players/sam-dekker-1.html',
#  'https://www.sports-reference.com/cbb/players/jerian-grant-1.html',
#  'https://www.sports-reference.com/cbb/players/dangelo-russell-1.html',
#  'https://www.sports-reference.com/cbb/players/delon-wright-1.html',
#  'https://www.sports-reference.com/cbb/players/justin-anderson-1.html',
#  'https://www.sports-reference.com/cbb/players/bobby-portis-1.html',
#  'https://www.sports-reference.com/cbb/players/rondae-hollis-jefferson-1.html',
#  'https://www.sports-reference.com/cbb/players/tyus-jones-1.html',
#  'https://www.sports-reference.com/cbb/players/jarell-martin-1.html',
#  'https://www.sports-reference.com/cbb/players/larry-nance-2.html',
#  'https://www.sports-reference.com/cbb/players/rj-hunter-1.html',
#  'https://www.sports-reference.com/cbb/players/chris-mccullough-1.html',
#  'https://www.sports-reference.com/cbb/players/kevon-looney-1.html',
#  'https://www.sports-reference.com/cbb/players/montrezl-harrell-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-mickey-1.html',
#  'https://www.sports-reference.com/cbb/players/anthony-brown-5.html',
#  'https://www.sports-reference.com/cbb/players/rakeem-christmas-1.html',
#  'https://www.sports-reference.com/cbb/players/richaun-holmes-1.html',
#  'https://www.sports-reference.com/cbb/players/pat-connaughton-1.html',
#  'https://www.sports-reference.com/cbb/players/olivier-hanlan-1.html',
#  'https://www.sports-reference.com/cbb/players/joseph-young-1.html',
#  'https://www.sports-reference.com/cbb/players/andrew-harrison-1.html',
#  'https://www.sports-reference.com/cbb/players/marcus-thornton-1.html',
#  'https://www.sports-reference.com/cbb/players/norman-powell-1.html',
#  'https://www.sports-reference.com/cbb/players/dakari-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/aaron-white-3.html',
#  'https://www.sports-reference.com/cbb/players/tyler-harvey-1.html',
#  'https://www.sports-reference.com/cbb/players/branden-dawson-1.html',
#  'https://www.sports-reference.com/cbb/players/jp-tokoto-1.html',
#  'https://www.sports-reference.com/cbb/players/willie-cauley-stein-1.html',
#  'https://www.sports-reference.com/cbb/players/stanley-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/frank-kaminsky-1.html',
#  'https://www.sports-reference.com/cbb/players/thon-maker-1.html',
#  'https://www.sports-reference.com/cbb/players/taurean-prince-1.html',
#  'https://www.sports-reference.com/cbb/players/denzel-valentine-1.html',
#  'https://www.sports-reference.com/cbb/players/justin-jackson-4.html',
#  'https://www.sports-reference.com/cbb/players/wade-baldwin-1.html',
#  'https://www.sports-reference.com/cbb/players/henry-ellenson-1.html',
#  'https://www.sports-reference.com/cbb/players/malik-beasley-1.html',
#  'https://www.sports-reference.com/cbb/players/caris-levert-1.html',
#  'https://www.sports-reference.com/cbb/players/deandre-bembry-1.html',
#  'https://www.sports-reference.com/cbb/players/malachi-richardson-1.html',
#  'https://www.sports-reference.com/cbb/players/brice-johnson-1.html',
#  'https://www.sports-reference.com/cbb/players/caleb-swanigan-1.html',
#  'https://www.sports-reference.com/cbb/players/pascal-siakam-1.html',
#  'https://www.sports-reference.com/cbb/players/skal-labissiere-1.html',
#  'https://www.sports-reference.com/cbb/players/jaylen-brown-1.html',
#  'https://www.sports-reference.com/cbb/players/damian-jones-1.html',
#  'https://www.sports-reference.com/cbb/players/josh-hart-1.html',
#  'https://www.sports-reference.com/cbb/players/deyonta-davis-1.html',
#  'https://www.sports-reference.com/cbb/players/cheick-diallo-1.html',
#  'https://www.sports-reference.com/cbb/players/tyler-ulis-1.html',
#  'https://www.sports-reference.com/cbb/players/malcolm-brogdon-1.html',
#  'https://www.sports-reference.com/cbb/players/chinanu-onuaku-1.html',
#  'https://www.sports-reference.com/cbb/players/patrick-mccaw-1.html',
#  'https://www.sports-reference.com/cbb/players/diamond-stone-1.html',
#  'https://www.sports-reference.com/cbb/players/stephen-zimmermanjr-1.html',
#  'https://www.sports-reference.com/cbb/players/isaiah-whitehead-1.html',
#  'https://www.sports-reference.com/cbb/players/zhou-qi-1.html',
#  'https://www.sports-reference.com/cbb/players/demetrius-jackson-2.html',
#  'https://www.sports-reference.com/cbb/players/jake-layman-1.html',
#  'https://www.sports-reference.com/cbb/players/michael-gbinije-1.html',
#  'https://www.sports-reference.com/cbb/players/kris-dunn-1.html',
#  'https://www.sports-reference.com/cbb/players/georges-niang-1.html',
#  'https://www.sports-reference.com/cbb/players/ben-bentil-1.html',
#  'https://www.sports-reference.com/cbb/players/joel-bolomboy-1.html',
#  'https://www.sports-reference.com/cbb/players/kahlil-felder-1.html',
#  'https://www.sports-reference.com/cbb/players/marcus-paige-1.html',
#  'https://www.sports-reference.com/cbb/players/daniel-hamilton-1.html',
#  'https://www.sports-reference.com/cbb/players/isaiah-cousins-1.html',
#  'https://www.sports-reference.com/cbb/players/jaron-blossomgame-1.html',
#  'https://www.sports-reference.com/cbb/players/buddy-hield-1.html',
#  'https://www.sports-reference.com/cbb/players/marquese-chriss-1.html',
#  'https://www.sports-reference.com/cbb/players/jakob-poeltl-1.html',
#  'https://www.sports-reference.com/cbb/players/zach-collins-1.html',
#  'https://www.sports-reference.com/cbb/players/luke-kennard-1.html',
#  'https://www.sports-reference.com/cbb/players/donovan-mitchell-1.html',
#  'https://www.sports-reference.com/cbb/players/edrice-adebayo-1.html',
#  'https://www.sports-reference.com/cbb/players/justin-patton-1.html',
#  'https://www.sports-reference.com/cbb/players/dj-wilson-1.html',
#  'https://www.sports-reference.com/cbb/players/tj-leaf-1.html',
#  'https://www.sports-reference.com/cbb/players/john-collins-1.html',
#  'https://www.sports-reference.com/cbb/players/harry-giles-1.html',
#  'https://www.sports-reference.com/cbb/players/terrance-ferguson-1.html',
#  'https://www.sports-reference.com/cbb/players/jarrett-allen-1.html',
#  'https://www.sports-reference.com/cbb/players/og-anunoby-1.html',
#  'https://www.sports-reference.com/cbb/players/tyler-lydon-1.html',
#  'https://www.sports-reference.com/cbb/players/kyle-kuzma-1.html',
#  'https://www.sports-reference.com/cbb/players/tony-bradley-1.html',
#  'https://www.sports-reference.com/cbb/players/derrick-white-1.html',
#  'https://www.sports-reference.com/cbb/players/frank-jackson-2.html',
#  'https://www.sports-reference.com/cbb/players/davon-reed-1.html',
#  'https://www.sports-reference.com/cbb/players/wesley-iwundu-1.html',
#  'https://www.sports-reference.com/cbb/players/frank-mason-1.html',
#  'https://www.sports-reference.com/cbb/players/ivan-rabb-1.html',
#  'https://www.sports-reference.com/cbb/players/semi-ojeleye-1.html',
#  'https://www.sports-reference.com/cbb/players/jordan-bell-1.html',
#  'https://www.sports-reference.com/cbb/players/jawun-evans-1.html',
#  'https://www.sports-reference.com/cbb/players/dwayne-bacon-1.html',
#  'https://www.sports-reference.com/cbb/players/tyler-dorsey-1.html',
#  'https://www.sports-reference.com/cbb/players/thomas-bryant-1.html',
#  'https://www.sports-reference.com/cbb/players/damyean-dotson-1.html',
#  'https://www.sports-reference.com/cbb/players/dillon-brooks-1.html',
#  'https://www.sports-reference.com/cbb/players/ike-anigbogu-1.html',
#  'https://www.sports-reference.com/cbb/players/sindarius-thornwell-1.html',
#  'https://www.sports-reference.com/cbb/players/deaaron-fox-1.html',
#  'https://www.sports-reference.com/cbb/players/monte-morris-1.html',
#  'https://www.sports-reference.com/cbb/players/edmond-sumner-1.html',
#  'https://www.sports-reference.com/cbb/players/kadeem-allen-1.html',
#  'https://www.sports-reference.com/cbb/players/alec-peters-1.html',
#  'https://www.sports-reference.com/cbb/players/nigel-williams-goss-1.html']

# %% [markdown]
# Define function to srape draftee college stats from Sports Reference, extract data from the html and save to an excel file

# %%
def webscrape(player, url, csv_filename, columns):
    headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}
    response = requests.get(url, headers = headers, timeout=5)
    if response.status_code != 200:        
        print(response.status_code, url)
    else:  
        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find(id='div_players_per_game')
        table_body=table.find('tbody')
        season_unparsed = table_body.find_all('th',class_='left')
        school_conf_unparsed = table_body.find_all('td',class_='left')
        stats_unparsed = table_body.find_all('td',class_='right')
        seasons = []
        for item in season_unparsed:
            if str(item).find('ring') > 0:
                if str(item).count('href=') > 1:
                    season = str(item).split('<')[-6][-7:]
                    seasons.append(season)
                else:
                    season = str(item).split('<')[-5][-7:]
                    seasons.append(season)
            elif str(item).count('href=') > 1:
                season = str(item).split('<')[-4][-7:]
                seasons.append(season)
            else:
                season = str(item).split('<')[-3][-7:]
                seasons.append(season)
        school_conf = []
        for item in school_conf_unparsed:
            school_conf_dp = str(item).split('<')[-3].split('>')[-1]
            school_conf.append(school_conf_dp)
        drop=False
        stats = []
        for item in stats_unparsed:
            if str(item).find('Transfer') == -1:
                if str(item).find('dnp_rest') == -1:
                    stat = str(item).split('<')[-2].split('>')[-1]
                    stats.append(stat)
            elif school_conf[0] != school_conf[2]:
                del seasons[1]
            elif school_conf[2] != school_conf[4]:
                del seasons[2]
            elif school_conf[4] != school_conf[6]:
                del seasons[3]      
        data = []
        for index in range(0,len(seasons)):
            data.append([player, seasons[index],school_conf[index*2],school_conf[index*2+1],stats[index*26],stats[index*26+1],
                     stats[index*26+2],stats[index*26+3],stats[index*26+4],stats[index*26+5],stats[index*26+6],
                     stats[index*26+7],stats[index*26+8],stats[index*26+9],stats[index*26+10],stats[index*26+11],
                     stats[index*26+12],stats[index*26+13],stats[index*26+14],stats[index*26+15],stats[index*26+16],
                     stats[index*26+17],stats[index*26+18],stats[index*26+19],stats[index*26+20],stats[index*26+21],
                     stats[index*26+22],stats[index*26+23],stats[index*26+24],stats[index*26+25]])
        new_df = pd.DataFrame(data, columns = columns)
        old_df = pd.read_csv(csv_filename, index_col = 0)
        df_save = pd.concat([old_df, new_df])
        df_save.to_csv(csv_filename)

# %% [markdown]
# Run draftee college stats scraping function on list of player urls to create an excel file with college stats

# %%
columns=['Player','Season','School','Conf','G','GS','MP','FG','FGA','FG%','2P','2PA','2P%', '3P','3PA','3P%','FT','FTA','FT%',
         'ORB','DRB', 'TRB','AST','STL','BLK','TOV','PF','PTS','Blank','SOS']
csv_filename = 'college_stats.csv'
empty_df = pd.DataFrame(columns=columns)
empty_df.to_csv(csv_filename)
for player,url in zip(players,urls):
    webscrape(player, url, csv_filename, columns)
    print(player)
# Out:
# Blake Griffin
# Terrence Williams
# Gerald Henderson
# Tyler Hansbrough
# Earl Clark
# Austin Daye
# James Johnson
# Jrue Holiday
# Ty Lawson
# Jeff Teague
# Hasheem Thabeet
# Eric Maynor
# Darren Collison
# 404 https://www.sports-reference.com/cbb/players/omri-casspi-1.html
# Omri Casspi
# Byron Mullens
# Damion James
# 404 https://www.sports-reference.com/cbb/players/rodrigue-beaubois-1.html
# Rodrigue Beaubois
# Taj Gibson
# DeMarre Carroll
# Greivis Vasquez
# Wayne Ellington
# Toney Douglas
# James Harden
# Jeff Pendergraph
# Jermaine Taylor
# Dante Cunningham
# DaJuan Summers
# Sam Young
# DeJuan Blair
# Tyreke Evans
# Derrick Brown
# Jodie Meeks
# Marcus Thornton
# Chase Budinger
# Danny Green
# Gani Lawal
# Jack McClinton
# A.J. Price
# Luke Harangody
# Patrick Mills
# Jonny Flynn
# Stephen Curry
# Jordan Hill
# Demar DeRozan
# John Wall
# Paul George
# Cole Aldrich
# Xavier Henry
# Ed Davis
# Patrick Patterson
# Larry Sanders
# Luke Babbitt
# Eric Bledsoe
# Avery Bradley
# Evan Turner
# James Anderson
# Craig Brackins
# Trevor Booker
# Dominique Jones
# Jordan Crawford
# Daniel Orton
# Derrick Favors
# Lazar Hayward
# Dexter Pittman
# Hassan Whiteside
# Armon Johnson
# Terrico White
# Darington Hobson
# Andy Rautins
# Wesley Johnson
# Lance Stephenson
# Jarvis Varnado
# Devin Ebanks
# Jerome Jordan
# Tiny Gallon
# 404 https://www.sports-reference.com/cbb/players/ryan-richards-1.html
# Ryan Richards
# DeMarcus Cousins
# Solomon Alabi
# Willie Warren
# Derrick Caracter
# Stanley Robinson
# Ekpe Udoh
# Greg Monroe
# Al-Farouq Aminu
# Gordon Hayward
# Jimmer Fredette
# Klay Thompson
# Alec Burks
# Markieff Morris
# Marcus Morris
# Kawhi Leonard
# Nikola Vucevic
# Iman Shumpert
# Chris Singleton
# Tobias Harris
# Derrick Williams
# Nolan Smith
# Kenneth Faried
# Marshon Brooks
# Jordan Hamilton
# JaJuan Johnson
# Norris Cole
# Cory Joseph
# 404 https://www.sports-reference.com/cbb/players/enes-kanter-1.html
# Enes Kanter
# Jimmy Butler
# Justin Harper
# Kyle Singler
# Shelvin Mack
# Tyler Honeycutt
# Jordan Williams
# Trey Thompkins
# Chandler Parsons
# 404 https://www.sports-reference.com/cbb/players/jeremy-tyler-1.html
# Jeremy Tyler
# Tristan Thompson
# Jon Leuer
# Darius Morris
# Malcolm Lee
# Charles Jenkins
# Andrew Goudelock
# Travis Leslie
# Keith Benson
# Josh Selby
# Jon Diebler
# DeAndre Liggins
# E'Twaun Moore
# Isaiah Thomas
# Brandon Knight
# Kemba Walker
# Anthony Davis
# Austin Rivers
# Meyers Leonard
# Jeremy Lamb
# Kendall Marshall
# John Henson
# Moe Harkless
# Royce White
# Tyler Zeller
# Terrence Jones
# Andrew Nicholson
# Michael Kidd-Gilchrist
# Jared Sullinger
# Fab Melo
# John Jenkins
# Jared Cunningham
# Tony Wroten
# Miles Plumlee
# Arnett Moultrie
# Perry Jones
# Marquis Teague
# Bradley Beal
# Festus Ezeli
# Jeff Taylor
# 404 https://www.sports-reference.com/cbb/players/tomas-satoransky-1.html
# Tomas Satoransky
# Bernard James
# Jae Crowder
# Draymond Green
# Orlando Johnson
# Quincy Acy
# Quincy Miller
# Khris Middleton
# Dion Waiters
# Will Barton
# Tyshawn Taylor
# Doron Lamb
# Mike Scott
# Kim English
# Darius Miller
# Kevin Murphy
# Kyle O'Quinn
# Thomas Robinson
# Kris Joseph
# Darius Johnson-Odom
# Robbie Hummel
# Marcus Denmon
# Damian Lillard
# Harrison Barnes
# Terrence Ross
# Andre Drummond
# C.J. McCollum
# Michael Carter-Williams
# Steven Adams
# Kelly Olynyk
# Shabazz Muhammad
# 404 https://www.sports-reference.com/cbb/players/dennis-schroeder-1.html
# Dennis Schroeder
# Shane Larkin
# Victor Oladipo
# Tony Snell
# Gorgui Dieng
# Mason Plumlee
# Solomon Hill
# Tim Hardaway Jr
# Reggie Bullock
# Andre Roberson
# 404 https://www.sports-reference.com/cbb/players/rudy-gobert-1.html
# Rudy Gobert
# Archie Goodwin
# Otto Porter
# Allen Crabbe
# Carrick Felix
# Isaiah Canaan
# Glen Rice
# Ray McCallum
# Tony Mitchell
# Nate Wolters
# Jeff Withey
# Cody Zeller
# Grant Jerrett
# Jamaal Franklin
# Pierre Jackson
# 404 https://www.sports-reference.com/cbb/players/ricky-ledo-1.html
# Ricky Ledo
# Mike Muscala
# Erick Green
# Ryan Kelly
# Erik Murphy
# James Ennis
# Lorenzo Brown
# Colton Iverson
# Peyton Siva
# Deshaun Thomas
# Nerlens Noel
# Ben McLemore
# Kentavious Caldwell-Pope
# Trey Burke
# Elfrid Payton
# Doug McDermott
# Zach LaVine
# T.J. Warren
# Adreian Payne
# James Young
# Tyler Ennis
# Gary Harris
# Jordan Adams
# Rodney Hood
# Shabazz Napier
# P.J. Hairston
# C.J. Wilcox
# Kyle Anderson
# K.J. McDaniels
# Joe Harris
# Cleanthony Early
# Jarnell Stokes
# Johnny O'Bryant
# DeAndre Daniels
# Spencer Dinwiddie
# Jerami Grant
# Aaron Gordon
# Glenn Robinson
# Nick Johnson
# Markel Brown
# Dwight Powell
# Jordan Clarkson
# Russ Smith
# Lamar Patterson
# Cameron Bairstow
# 404 https://www.sports-reference.com/cbb/players/dante-exum-1.html
# Dante Exum
# Alec Brown
# 404 https://www.sports-reference.com/cbb/players/thanasis-antetokounmpo-1.html
# Thanasis Antetokounmpo
# Semaj Christon
# Devyn Marble
# Jordan McRae
# Xavier Thames
# Marcus Smart
# Cory Jefferson
# Julius Randle
# Nik Stauskas
# Noah Vonleh
# Justise Winslow
# Myles Turner
# Trey Lyles
# Devin Booker
# Cameron Payne
# Kelly Oubre
# Terry Rozier
# Rashad Vaughn
# Sam Dekker
# Jerian Grant
# D'Angelo Russell
# Delon Wright
# Justin Anderson
# Bobby Portis
# Rondae Hollis-Jefferson
# Tyus Jones
# Jarell Martin
# Larry Nance
# R.J. Hunter
# Chris McCullough
# Kevon Looney
# Montrezl Harrell
# Jordan Mickey
# Anthony Brown
# Rakeem Christmas
# Richaun Holmes
# Pat Connaughton
# Olivier Hanlan
# Joseph Young
# Andrew Harrison
# Marcus Thornton
# Norman Powell
# Dakari Johnson
# Aaron White
# Tyler Harvey
# Branden Dawson
# J.P. Tokoto
# Willie Cauley-Stein
# Stanley Johnson
# Frank Kaminsky
# 404 https://www.sports-reference.com/cbb/players/thon-maker-1.html
# Thon Maker
# Taurean Prince
# Denzel Valentine
# Justin Jackson
# Wade Baldwin
# Henry Ellenson
# Malik Beasley
# Caris LeVert
# DeAndre Bembry
# Malachi Richardson
# Brice Johnson
# Caleb Swanigan
# Pascal Siakam
# Skal Labissiere
# Jaylen Brown
# Damian Jones
# Josh Hart
# Deyonta Davis
# Cheick Diallo
# Tyler Ulis
# Malcolm Brogdon
# Chinanu Onuaku
# Patrick McCaw
# Diamond Stone
# Stephen Zimmerman
# Isaiah Whitehead
# 404 https://www.sports-reference.com/cbb/players/zhou-qi-1.html
# Zhou Qi
# Demetrius Jackson
# Jake Layman
# Michael Gbinije
# Kris Dunn
# Georges Niang
# Ben Bentil
# Joel Bolomboy
# Kay Felder
# Marcus Paige
# Daniel Hamilton
# Isaiah Cousins
# Jaron Blossomgame
# Buddy Hield
# Marquese Chriss
# Jakob Poeltl
# Zach Collins
# Luke Kennard
# Donovan Mitchell
# Bam Adebayo
# Justin Patton
# D.J. Wilson
# T.J. Leaf
# John Collins
# Harry Giles
# 404 https://www.sports-reference.com/cbb/players/terrance-ferguson-1.html
# Terrance Ferguson
# Jarrett Allen
# OG Anunoby
# Tyler Lydon
# Kyle Kuzma
# Tony Bradley
# Derrick White
# Frank Jackson
# Davon Reed
# Wesley Iwundu
# Frank Mason
# Ivan Rabb
# Semi Ojeleye
# Jordan Bell
# Jawun Evans
# Dwayne Bacon
# Tyler Dorsey
# Thomas Bryant
# Damyean Dotson
# Dillon Brooks
# Ike Anigbogu
# Sindarius Thornwell
# De'Aaron Fox
# Monte Morris
# Edmond Sumner
# Kadeem Allen
# Alec Peters
# Nigel Williams-Goss

# %% [markdown]
# Read draftee college stats csv to df and convert season column from 2 year value to a single year value based on second year in season

# %%
college_df = pd.read_csv('college_stats.csv', index_col = 0)
college_df['Year'] = college_df['Season'].apply(lambda x:x.split('-')[0]).astype(int)+1
college_df.head()
# Out:
#               Player   Season      School      Conf   G  GS    MP   FG   FGA  \
# 0      Blake Griffin  2007-08    Oklahoma    Big 12  33  28  28.4  5.6   9.8
# 1      Blake Griffin  2008-09    Oklahoma    Big 12  35  35  33.3  8.6  13.1
# 0  Terrence Williams  2005-06  Louisville  Big East  33  21  25.1  3.2   8.1
# 1  Terrence Williams  2006-07  Louisville  Big East  34  34  33.0  4.6  12.7
# 2  Terrence Williams  2007-08  Louisville  Big East  36  36  35.9  4.1   9.9
#
#      FG%  ...   TRB  AST  STL  BLK  TOV   PF   PTS  Blank   SOS  Year
# 0  0.568  ...   9.1  1.8  1.0  0.8  2.3  2.5  14.7    NaN  7.85  2008
# 1  0.654  ...  14.4  2.3  1.1  1.2  3.3  2.5  22.7    NaN  6.88  2009
# 0  0.391  ...   4.7  2.1  1.0  0.3  1.7  1.8   8.4    NaN  6.50  2006
# 1  0.367  ...   7.0  3.8  1.3  0.7  2.4  2.1  12.4    NaN  7.69  2007
# 2  0.411  ...   7.2  4.5  1.3  0.8  2.9  1.9  11.1    NaN  8.00  2008
#
# [5 rows x 31 columns]

# %% [markdown]
# Create df with stats for each draftees last college season only from df with stats for all draftee seasons

# %%
players_list = list(college_df.groupby('Player').first().index)
college_columns = list(college_df.columns)
college_season_df = pd.DataFrame(columns=college_columns)
for player in players_list:
    max_year = int(college_df[college_df['Player']==player].groupby('Player')['Year'].max())
    max_year_df = college_df[(college_df['Player']==player)&(college_df['Year']==max_year)]
    college_season_df = pd.concat([college_season_df,max_year_df],axis=0)
college_season_df.head(50)
# Out:
#              Player   Season                 School      Conf   G  GS    MP  \
# 2        A.J. Price  2008-09                  UConn  Big East  35  35  31.8
# 0      Aaron Gordon  2013-14                Arizona    Pac-12  38  38  31.2
# 3       Aaron White  2014-15                   Iowa   Big Ten  34  34  31.5
# 3     Adreian Payne  2013-14         Michigan State   Big Ten  31  28  28.1
# 1   Al-Farouq Aminu  2009-10            Wake Forest       ACC  31  30  31.3
# 3        Alec Brown  2013-14              Green Bay   Horizon  30  30  30.3
# 1        Alec Burks  2010-11               Colorado    Big 12  38  37  31.4
# 3       Alec Peters  2016-17             Valparaiso   Horizon  29  29  35.1
# 2      Allen Crabbe  2012-13             California    Pac-12  33  33  36.2
# 0    Andre Drummond  2011-12                  UConn  Big East  34  30  28.4
# 2    Andre Roberson  2012-13               Colorado    Pac-12  31  30  33.4
# 3  Andrew Goudelock  2010-11  College of Charleston  Southern  37  37  35.2
# 1   Andrew Harrison  2014-15               Kentucky       SEC  39  39  25.5
# 3  Andrew Nicholson  2011-12        St. Bonaventure      A-10  32  32  30.1
# 3      Andy Rautins  2009-10               Syracuse  Big East  35  35  32.5
# 4     Anthony Brown  2014-15               Stanford    Pac-12  37  36  35.7
# 0     Anthony Davis  2011-12               Kentucky       SEC  40  40  32.0
# 0    Archie Goodwin  2012-13               Kentucky       SEC  33  33  31.8
# 2     Armon Johnson  2009-10                 Nevada       WAC  34  34  34.5
# 2   Arnett Moultrie  2011-12      Mississippi State       SEC  30  30  35.8
# 1       Austin Daye  2008-09                Gonzaga       WCC  34  33  26.3
# 0     Austin Rivers  2011-12                   Duke       ACC  34  33  33.2
# 0     Avery Bradley  2009-10                  Texas    Big 12  34  32  29.5
# 0       Bam Adebayo  2016-17               Kentucky       SEC  38  38  30.1
# 1        Ben Bentil  2015-16             Providence  Big East  35  33  34.2
# 0      Ben McLemore  2012-13                 Kansas    Big 12  37  36  32.2
# 1     Bernard James  2011-12          Florida State       ACC  35  35  28.0
# 1     Blake Griffin  2008-09               Oklahoma    Big 12  35  35  33.3
# 1      Bobby Portis  2014-15               Arkansas       SEC  36  36  29.9
# 0      Bradley Beal  2011-12                Florida       SEC  37  37  34.2
# 3    Branden Dawson  2014-15         Michigan State   Big Ten  35  32  30.1
# 0    Brandon Knight  2010-11               Kentucky       SEC  38  38  35.9
# 3     Brice Johnson  2015-16                    UNC       ACC  40  39  28.0
# 3       Buddy Hield  2015-16               Oklahoma    Big 12  37  37  35.4
# 0     Byron Mullens  2008-09             Ohio State   Big Ten  33   2  20.3
# 3     C.J. McCollum  2012-13                 Lehigh   Patriot  12  11  31.0
# 3       C.J. Wilcox  2013-14             Washington    Pac-12  32  31  34.9
# 1    Caleb Swanigan  2016-17                 Purdue   Big Ten  35  35  32.5
# 3  Cameron Bairstow  2013-14             New Mexico       MWC  34  34  32.9
# 1     Cameron Payne  2014-15           Murray State       OVC  35  35  32.2
# 3      Caris LeVert  2015-16               Michigan   Big Ten  15  14  30.9
# 2     Carrick Felix  2012-13          Arizona State    Pac-12  35  34  35.3
# 3  Chandler Parsons  2010-11                Florida       SEC  36  35  34.1
# 3   Charles Jenkins  2010-11                Hofstra       CAA  33  33  37.3
# 2    Chase Budinger  2008-09                Arizona    Pac-10  35  35  37.6
# 0     Cheick Diallo  2015-16                 Kansas    Big 12  27   1   7.5
# 1    Chinanu Onuaku  2015-16             Louisville       ACC  31  29  24.6
# 0  Chris McCullough  2014-15               Syracuse       ACC  16  16  28.1
# 2   Chris Singleton  2010-11          Florida State       ACC  28  25  29.1
# 1  Cleanthony Early  2013-14          Wichita State       MVC  36  36  27.4
#
#     FG   FGA    FG%  ...   TRB  AST  STL  BLK  TOV   PF   PTS  Blank    SOS  \
# 2  4.9  11.9  0.408  ...   3.5  4.7  0.7  0.0  2.7  1.3  14.7    NaN   8.57
# 0  5.0  10.1  0.495  ...   8.0  2.0  0.9  1.0  1.4  2.4  12.4    NaN   9.04
# 3  5.0   9.6  0.521  ...   7.3  1.4  1.3  0.5  1.2  1.6  16.4    NaN   8.39
# 3  5.7  11.4  0.503  ...   7.3  1.3  0.5  0.9  2.0  2.6  16.4    NaN   9.38
# 1  5.4  12.1  0.447  ...  10.7  1.3  1.4  1.4  3.2  2.9  15.8    NaN   8.85
# 3  5.5  11.6  0.476  ...   5.7  1.0  0.5  3.1  2.2  2.2  15.3    NaN   0.11
# 1  6.6  14.1  0.469  ...   6.5  2.9  1.1  0.3  2.6  2.3  20.5    NaN   5.61
# 3  7.5  16.1  0.466  ...  10.1  2.2  0.8  0.4  2.4  2.2  23.0    NaN  -1.59
# 2  6.5  14.2  0.459  ...   6.1  2.6  1.1  0.7  2.5  2.1  18.4    NaN   7.77
# 0  4.6   8.6  0.538  ...   7.6  0.4  0.8  2.7  1.5  2.2  10.0    NaN   8.07
# 2  4.3   8.9  0.480  ...  11.2  1.4  2.2  1.3  2.4  2.5  10.9    NaN   7.95
# 3  8.6  18.9  0.455  ...   3.9  4.2  0.9  0.2  3.2  1.8  23.7    NaN  -1.05
# 1  2.6   6.8  0.378  ...   2.2  3.6  1.0  0.2  1.6  1.8   9.3    NaN   8.67
# 3  6.9  12.0  0.571  ...   8.4  1.0  0.7  2.0  2.5  2.8  18.5    NaN   2.84
# 3  3.7   8.5  0.438  ...   3.4  4.9  2.0  0.2  2.8  2.2  12.1    NaN   7.21
# 4  4.8  11.0  0.431  ...   6.9  2.5  0.8  0.2  1.9  2.1  14.8    NaN   7.33
# 0  5.3   8.4  0.623  ...  10.4  1.3  1.4  4.7  1.0  2.0  14.2    NaN   7.93
# 0  4.8  10.8  0.440  ...   4.6  2.7  1.1  0.5  3.1  2.9  14.1    NaN   5.78
# 2  6.4  13.0  0.495  ...   3.4  5.6  0.8  0.4  3.4  1.8  15.7    NaN   2.56
# 2  6.0  10.9  0.549  ...  10.5  1.2  0.8  0.8  2.4  2.2  16.4    NaN   4.86
# 1  4.7   9.8  0.477  ...   6.8  1.1  0.7  2.1  2.1  2.9  12.7    NaN   3.55
# 0  5.1  11.8  0.433  ...   3.4  2.1  1.0  0.0  2.3  2.2  15.5    NaN   8.40
# 0  4.7  10.8  0.432  ...   2.9  2.1  1.3  0.5  1.5  2.4  11.6    NaN   7.38
# 0  4.5   7.5  0.599  ...   8.0  0.8  0.7  1.5  1.7  2.6  13.0    NaN  10.49
# 1  7.0  15.2  0.462  ...   7.7  1.1  0.9  1.0  1.9  2.8  21.1    NaN   8.46
# 0  5.4  10.8  0.495  ...   5.2  2.0  1.0  0.7  2.1  1.9  15.9    NaN   7.54
# 1  4.5   7.4  0.606  ...   8.1  0.5  0.7  2.3  2.1  1.9  10.8    NaN   7.62
# 1  8.6  13.1  0.654  ...  14.4  2.3  1.1  1.2  3.3  2.5  22.7    NaN   6.88
# 1  6.9  12.9  0.536  ...   8.9  1.2  1.1  1.4  1.6  2.2  17.5    NaN   6.79
# 0  4.7  10.6  0.445  ...   6.7  2.2  1.4  0.8  2.1  2.1  14.8    NaN   7.33
# 3  5.2   9.7  0.535  ...   9.1  1.7  1.2  1.7  1.9  2.1  11.9    NaN  10.00
# 0  5.7  13.5  0.423  ...   4.0  4.2  0.7  0.2  3.2  2.2  17.3    NaN   8.91
# 3  6.7  10.9  0.614  ...  10.4  1.5  1.1  1.5  1.8  2.7  17.0    NaN  10.69
# 3  8.1  16.2  0.501  ...   5.7  2.0  1.1  0.5  3.1  2.1  25.0    NaN  11.14
# 0  3.6   5.7  0.638  ...   4.7  0.3  0.5  1.1  1.5  2.1   8.8    NaN   8.23
# 3  8.0  16.2  0.495  ...   5.0  2.9  1.4  0.3  2.7  1.8  23.9    NaN  -3.01
# 3  6.2  13.6  0.453  ...   3.7  2.5  1.0  1.0  1.7  2.3  18.3    NaN   6.45
# 1  6.3  12.0  0.527  ...  12.5  3.1  0.4  0.8  3.4  2.8  18.5    NaN   8.79
# 3  7.0  12.5  0.556  ...   7.4  1.6  0.6  1.5  2.0  2.1  20.4    NaN   4.84
# 1  7.0  15.3  0.456  ...   3.7  6.0  1.9  0.5  2.5  2.1  20.2    NaN  -2.81
# 3  5.5  10.8  0.506  ...   5.3  4.9  1.0  0.2  1.7  1.2  16.5    NaN   7.92
# 2  5.4  10.8  0.500  ...   8.1  1.6  1.4  1.1  2.0  3.0  14.6    NaN   4.60
# 3  4.3   9.0  0.480  ...   7.8  3.8  0.9  0.4  2.3  1.9  11.3    NaN   7.57
# 3  7.5  14.6  0.517  ...   3.4  4.8  1.7  0.7  2.2  2.0  22.6    NaN   0.13
# 2  6.3  13.0  0.480  ...   6.2  3.4  1.4  0.5  2.4  1.9  18.0    NaN   8.80
# 0  1.2   2.1  0.569  ...   2.5  0.0  0.3  0.9  0.6  1.4   3.0    NaN  11.22
# 1  4.4   7.1  0.620  ...   8.5  1.6  0.8  2.0  2.1  3.0   9.9    NaN   7.74
# 0  3.4   7.1  0.478  ...   6.9  1.1  1.7  2.1  2.2  2.6   9.3    NaN   7.68
# 2  4.4  10.2  0.434  ...   6.8  1.2  2.0  1.5  2.2  3.2  13.1    NaN   6.45
# 1  5.2  10.7  0.484  ...   5.9  0.8  0.8  0.8  1.9  2.3  16.4    NaN   1.74
#
#    Year
# 2  2009
# 0  2014
# 3  2015
# 3  2014
# 1  2010
# 3  2014
# 1  2011
# 3  2017
# 2  2013
# 0  2012
# 2  2013
# 3  2011
# 1  2015
# 3  2012
# 3  2010
# 4  2015
# 0  2012
# 0  2013
# 2  2010
# 2  2012
# 1  2009
# 0  2012
# 0  2010
# 0  2017
# 1  2016
# 0  2013
# 1  2012
# 1  2009
# 1  2015
# 0  2012
# 3  2015
# 0  2011
# 3  2016
# 3  2016
# 0  2009
# 3  2013
# 3  2014
# 1  2017
# 3  2014
# 1  2015
# 3  2016
# 2  2013
# 3  2011
# 3  2011
# 2  2009
# 0  2016
# 1  2016
# 0  2015
# 2  2011
# 1  2014
#
# [50 rows x 31 columns]

# %% [markdown]
# Check games sample size for the draftees' final college season to ensure sufficiency

# %%
print(college_season_df.columns)
college_season_df.sort_values(by='G').head(5)
# Out:
# Index(['Player', 'Season', 'School', 'Conf', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Blank',
#        'SOS', 'Year'],
#       dtype='object')
#               Player   Season    School     Conf   G  GS    MP   FG   FGA  \
# 3      C.J. McCollum  2012-13    Lehigh  Patriot  12  11  31.0  8.0  16.2
# 3       Caris LeVert  2015-16  Michigan  Big Ten  15  14  30.9  5.5  10.8
# 1         OG Anunoby  2016-17   Indiana  Big Ten  16  10  25.1  4.3   7.6
# 0   Chris McCullough  2014-15  Syracuse      ACC  16  16  28.1  3.4   7.1
# 2  Spencer Dinwiddie  2013-14  Colorado   Pac-12  17  17  31.1  3.6   7.7
#
#      FG%  ...  TRB  AST  STL  BLK  TOV   PF   PTS  Blank   SOS  Year
# 3  0.495  ...  5.0  2.9  1.4  0.3  2.7  1.8  23.9    NaN -3.01  2013
# 3  0.506  ...  5.3  4.9  1.0  0.2  1.7  1.2  16.5    NaN  7.92  2016
# 1  0.557  ...  5.4  1.4  1.3  1.3  1.6  2.1  11.1    NaN  8.16  2017
# 0  0.478  ...  6.9  1.1  1.7  2.1  2.2  2.6   9.3    NaN  7.68  2015
# 2  0.466  ...  3.1  3.8  1.5  0.2  1.8  1.9  14.7    NaN  8.80  2014
#
# [5 rows x 31 columns]

# %% [markdown]
# # Merge dataframes and format

# %% [markdown]
# Drop uneeded columns from  dfs with draftees' nba stats, college sats and combine stats and merge 3 dfs into a single draft df

# %%
nba_category_df=nba_df[['Player','Rotation']]
college_season_df.drop(columns=['Season','School','Conf','Blank','Year'],inplace=True)
draft_df = pd.merge(combine_df,nba_category_df,on=['Player','Player'], how='inner')
draft_df = pd.merge(draft_df,college_season_df,on=['Player','Player'], how='inner')
print(draft_df.columns)
draft_df.head()
# Out:
# Index(['Player', 'Year', 'Draft pick', 'Height (No Shoes)',
#        'Height (With Shoes)', 'Wingspan', 'Standing reach', 'Vertical (Max)',
#        'Vertical (Max Reach)', 'Vertical (No Step)',
#        'Vertical (No Step Reach)', 'Weight', 'Body Fat', 'Hand (Length)',
#        'Hand (Width)', 'Bench', 'Agility', 'Sprint', 'Rotation', 'G', 'GS',
#        'MP', 'FG', 'FGA', 'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT',
#        'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'SOS'],
#       dtype='object')
#               Player  Year  Draft pick  Height (No Shoes)  \
# 0      Blake Griffin  2009         1.0              80.50
# 1  Terrence Williams  2009        11.0              77.00
# 2   Gerald Henderson  2009        12.0              76.00
# 3   Tyler Hansbrough  2009        13.0              80.25
# 4         Earl Clark  2009        14.0              80.50
#
#    Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                82.00     83.25           105.0            35.5
# 1                78.25     81.00           103.5            37.0
# 2                77.00     82.25           102.5            35.0
# 3                81.50     83.50           106.0            34.0
# 4                82.25     86.50           109.5            33.0
#
#    Vertical (Max Reach)  Vertical (No Step)  ...  ORB   DRB   TRB  AST  STL  \
# 0                 140.5                32.0  ...  3.9  10.5  14.4  2.3  1.1
# 1                 140.5                30.5  ...  1.4   7.2   8.6  5.0  2.3
# 2                 137.5                31.5  ...  1.2   3.7   4.9  2.5  1.2
# 3                 140.0                27.5  ...  3.0   5.1   8.1  1.0  1.2
# 4                 142.5                28.5  ...  2.8   5.9   8.7  3.2  1.0
#
#    BLK  TOV   PF   PTS   SOS
# 0  1.2  3.3  2.5  22.7  6.88
# 1  0.8  2.3  1.7  12.5  8.41
# 2  0.8  2.2  1.7  16.5  9.07
# 3  0.4  1.9  2.3  20.7  8.35
# 4  1.4  3.2  1.9  14.2  8.41
#
# [5 rows x 44 columns]

# %% [markdown]
# Replace missing values in draft df with estimated values

# %%
def max_reach_map(row):
    if row['Vertical (Max Reach)'] > 0:
        max_reach = row['Vertical (Max Reach)']
    else:
        max_reach = row['Wingspan']/draft_df['Wingspan'].mean()*draft_df['Vertical (Max Reach)'].mean()
        - .5*draft_df['Vertical (Max Reach)'].std()
    return max_reach
draft_df['Vertical (Max Reach)'] = draft_df.apply(max_reach_map,axis=1)


def max_vert_map(row):
    if row['Vertical (Max)'] > 0:
        max_vert = row['Vertical (Max)']
    else:
        max_vert = row['Vertical (Max Reach)'] - row['Standing reach']
    return max_vert
draft_df['Vertical (Max)'] = draft_df.apply(max_vert_map,axis=1)


def stepless_reach_map(row):
    if row['Vertical (No Step Reach)'] > 0:
        stepless_reach = row['Vertical (No Step Reach)']
    else:
        stepless_reach = row['Wingspan']/draft_df['Wingspan'].mean()*draft_df['Vertical (No Step Reach)'].mean()
        -.5*draft_df['Vertical (No Step Reach)'].std()
    return stepless_reach
draft_df['Vertical (No Step Reach)'] = draft_df.apply(stepless_reach_map,axis=1)


def stepless_vert_map(row):
    if row['Vertical (No Step)'] > 0:
        stepless_vert = row['Vertical (No Step)']
    else:
        stepless_vert = row['Vertical (No Step Reach)'] - row['Standing reach']
    return stepless_vert
draft_df['Vertical (No Step)'] = draft_df.apply(stepless_vert_map,axis=1)


def weight_map(row):
    if row['Weight'] > 0:
        weight = row['Weight']    
    else:
        weight = row['Height (No Shoes)']/draft_df['Height (No Shoes)'].mean()*draft_df['Weight'].mean()
    return weight
draft_df['Weight'] = draft_df.apply(weight_map,axis=1)


def body_fat_map(row):
    if row['Body Fat'] > 0:
        body_fat = row['Body Fat']    
    else:
        body_fat = draft_df['Body Fat'].mean() + draft_df['Body Fat'].std()
    return body_fat
draft_df['Body Fat'] = draft_df.apply(body_fat_map,axis=1)


def hand_length_map(row):
    if row['Hand (Length)'] > 0:
        hand_length = row['Hand (Length)'] 
    else: 
        hand_length = row['Wingspan']/draft_df['Wingspan'].mean()*draft_df['Hand (Length)'].mean()
        -.5*draft_df['Hand (Length)'].std()
    return hand_length
draft_df['Hand (Length)'] = draft_df.apply(hand_length_map,axis=1)


def hand_width_map(row):
    if row['Hand (Width)'] > 0:
        hand_width = row['Hand (Width)'] 
    else: 
        hand_width = row['Wingspan']/draft_df['Wingspan'].mean()*draft_df['Hand (Width)'].mean()
        -.5*draft_df['Hand (Width)'].std()
    return hand_width
draft_df['Hand (Width)'] = draft_df.apply(hand_width_map,axis=1)


def bench_map(row):
    if row['Bench'] > 0:
         bench = row['Bench']
    else:
        bench = row['Weight']/draft_df['Weight'].mean()*draft_df['Bench'].mean()
        -.5*draft_df['Bench'].std()
    return bench
draft_df['Bench'] = draft_df.apply(bench_map,axis=1)


def agility_map(row):
    if row['Agility'] > 0:
         agility = row['Agility']
    else:
        agility = row['Height (With Shoes)']/draft_df['Height (With Shoes)'].mean()*draft_df['Agility'].mean()
        +.5*draft_df['Agility'].std()
    return agility
draft_df['Agility'] = draft_df.apply(agility_map,axis=1)


def sprint_map(row):
    if row['Sprint'] > 0:
        sprint = row['Sprint']
    else:
        sprint = row['Height (With Shoes)']/draft_df['Height (With Shoes)'].mean()*draft_df['Sprint'].mean()
        +.5*draft_df['Sprint'].std()
    return sprint
draft_df['Sprint'] = draft_df.apply(sprint_map,axis=1)


def three_percent_map(row):
    if row['3P%'] > 0:
        three_percent = row['3P%']
    else:
        three_percent = 0
    return three_percent
draft_df['3P%'] = draft_df.apply(three_percent_map,axis=1)

# %% [markdown]
# Create interaction features within draft df

# %%
draft_df['Net TOV'] = draft_df['STL'] - draft_df['TOV']
draft_df['BMI'] = draft_df['Weight'] / draft_df['Height (No Shoes)']
draft_df['TS%'] = (draft_df['2P'] + 1.5*draft_df['3P'] + .5*draft_df['FT']) / (draft_df['2PA'] + draft_df['3PA'] 
                    + .5*draft_df['FTA'])
draft_df['EFG%'] = (draft_df['2P'] + 1.5*draft_df['3P']) / (draft_df['2PA'] + draft_df['3PA'])
draft_df['Speed'] = (draft_df['Agility'] + 3.5*draft_df['Sprint'])/2
draft_df['Range'] = draft_df['Standing reach'] / draft_df['Speed']
draft_df['Scoring Impact'] = draft_df['PTS'] * draft_df['TS%']
draft_df['Arm Length'] = (draft_df['Wingspan'] - draft_df['Height (With Shoes)'])/draft_df['Height (With Shoes)']
draft_df['Adj. Scoring Impact'] = draft_df['PTS'] * (1-((1-draft_df['TS%'])*.56)) +  .525*draft_df['SOS']

# %% [markdown]
# # EDA

# %% [markdown]
# Calculate descriptive statistics for first 20 feature columns

# %%
draft_df.describe().iloc[:,0:20]
# Out:
#               Year  Draft pick  Height (No Shoes)  Height (With Shoes)  \
# count   361.000000  361.000000         361.000000           361.000000
# mean   2012.911357   28.975069          77.566482            78.867036
# std       2.541414   15.993295           3.219797             3.217786
# min    2009.000000    1.000000          68.250000            69.500000
# 25%    2011.000000   15.000000          75.250000            76.750000
# 50%    2013.000000   29.000000          77.500000            79.000000
# 75%    2015.000000   42.000000          80.250000            81.500000
# max    2017.000000   60.000000          85.250000            86.500000
#
#         Wingspan  Standing reach  Vertical (Max)  Vertical (Max Reach)  \
# count  361.00000      361.000000      361.000000            361.000000
# mean    82.43241      103.215374       35.419009            138.634383
# std      3.86055        4.860146        3.486303              4.677001
# min     70.00000       88.500000       25.000000            117.492432
# 25%     79.75000      100.000000       33.000000            135.500000
# 50%     82.50000      103.500000       35.500000            139.000000
# 75%     85.25000      107.000000       37.500000            141.500000
# max     91.00000      113.000000       44.000000            151.481314
#
#        Vertical (No Step)  Vertical (No Step Reach)      Weight    Body Fat  \
# count          361.000000                361.000000  361.000000  361.000000
# mean            29.876626                133.092000  214.688654    7.132623
# std              3.018277                  4.850139   25.027136    2.450986
# min             22.500000                112.815134  149.000000    3.200000
# 25%             28.000000                130.000000  196.000000    5.300000
# 50%             30.000000                133.500000  214.000000    6.600000
# 75%             32.000000                136.500000  231.000000    8.300000
# max             38.000000                145.450941  303.000000   20.800000
#
#        Hand (Length)  Hand (Width)       Bench     Agility      Sprint  \
# count     361.000000    361.000000  361.000000  361.000000  361.000000
# mean        8.716126      9.333898   10.590127   11.318208    3.292781
# std         0.464349      0.691066    3.879653    0.537302    0.132876
# min         7.500000      7.000000    1.000000   10.070000    2.938079
# 25%         8.500000      8.750000    9.000000   10.960000    3.200000
# 50%         8.750000      9.250000   10.375992   11.240000    3.271478
# 75%         9.000000      9.750000   12.352371   11.640000    3.380000
# max        10.250000     11.750000   23.000000   13.440000    3.810000
#
#          Rotation          MP          FG
# count  361.000000  361.000000  361.000000
# mean     0.279778   31.207756    5.469806
# std      0.449513    4.444422    1.356651
# min      0.000000    7.500000    1.200000
# 25%      0.000000   29.500000    4.600000
# 50%      0.000000   32.000000    5.500000
# 75%      1.000000   34.200000    6.300000
# max      1.000000   38.100000    9.800000

# %% [markdown]
# Calculate descriptive statistics for second set of 20 feature columns

# %%
draft_df.describe().iloc[:,20:40]
# Out:
#               FGA         FG%          2P         2PA         2P%          3P  \
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000
# mean    11.309141    0.489418    4.271191    8.104709    0.526163    1.196953
# std      2.995478    0.058213    1.331583    2.353627    0.053544    0.926773
# min      2.100000    0.369000    0.800000    1.600000    0.376000    0.000000
# 25%      9.400000    0.447000    3.400000    6.500000    0.492000    0.300000
# 50%     11.300000    0.477000    4.300000    8.100000    0.522000    1.200000
# 75%     13.200000    0.525000    5.200000    9.700000    0.559000    1.900000
# max     20.700000    0.676000    8.900000   15.300000    0.701000    4.000000
#
#               3PA         3P%         FT         FTA         FT%         ORB  \
# count  361.000000  361.000000  361.00000  361.000000  361.000000  361.000000
# mean     3.208864    0.315598    3.49723    4.727147    0.733861    1.758449
# std      2.307362    0.148739    1.33112    1.628576    0.093818    1.002575
# min      0.000000    0.000000    0.50000    0.600000    0.295000    0.200000
# 25%      1.100000    0.288000    2.50000    3.500000    0.679000    0.900000
# 50%      3.300000    0.357000    3.40000    4.600000    0.746000    1.700000
# 75%      4.900000    0.396000    4.30000    5.900000    0.801000    2.500000
# max      9.900000    1.000000    7.30000    9.300000    0.917000    5.700000
#
#               DRB         TRB         AST         STL         BLK         TOV  \
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000
# mean     4.502770    6.255125    2.533518    1.158449    0.916066    2.132687
# std      1.650923    2.437812    1.711744    0.522804    0.876684    0.670726
# min      1.800000    2.200000    0.000000    0.200000    0.000000    0.600000
# 25%      3.200000    4.300000    1.300000    0.800000    0.300000    1.700000
# 50%      4.200000    5.900000    2.100000    1.100000    0.700000    2.100000
# 75%      5.700000    8.100000    3.400000    1.500000    1.300000    2.500000
# max     10.500000   14.500000    9.800000    2.900000    5.400000    4.400000
#
#                PF         PTS
# count  361.000000  361.000000
# mean     2.221053   15.626316
# std      0.489955    4.097296
# min      1.000000    3.000000
# 25%      1.900000   13.100000
# 50%      2.200000   15.900000
# 75%      2.600000   18.000000
# max      4.100000   28.900000

# %% [markdown]
# Calculate descriptive statistics for remaining feature columns

# %%
draft_df.describe().iloc[:,40:60]
# Out:
#               SOS     Net TOV         BMI         TS%        EFG%       Speed  \
# count  361.000000  361.000000  361.000000  361.000000  361.000000  361.000000
# mean     6.827313   -0.974238    2.762400    0.571799    0.538928   11.421470
# std      3.335459    0.681849    0.246635    0.041027    0.046790    0.441894
# min     -5.390000   -3.000000    2.167273    0.473988    0.439394   10.190757
# 25%      5.890000   -1.400000    2.595318    0.543624    0.505102   11.107500
# 50%      7.790000   -1.000000    2.750789    0.569322    0.535211   11.347500
# 75%      8.670000   -0.500000    2.907895    0.598485    0.568627   11.702500
# max     12.750000    1.200000    3.751553    0.720000    0.707792   13.195000
#
#             Range  Scoring Impact  Arm Length  Adj. Scoring Impact
# count  361.000000      361.000000  361.000000           361.000000
# mean     9.040002        8.971301    0.045261            15.483847
# std      0.341229        2.566550    0.026347             3.071602
# min      7.850965        1.730769   -0.026786             6.101731
# 25%      8.853721        7.365236    0.026866            13.523766
# 50%      9.057130        8.912621    0.045139            15.400468
# 75%      9.270678       10.494585    0.064516            17.474489
# max      9.730708       17.171967    0.110063            26.181833

# %% [markdown]
# Calculate correlations for desired columns

# %%
draft_df.corr()['Vertical (No Step Reach)']
# Out:
# Year                        0.061263
# Draft pick                 -0.200253
# Height (No Shoes)           0.787159
# Height (With Shoes)         0.783942
# Wingspan                    0.849011
# Standing reach              0.806768
# Vertical (Max)              0.119716
# Vertical (Max Reach)        0.927597
# Vertical (No Step)          0.307835
# Vertical (No Step Reach)    1.000000
# Weight                      0.642371
# Body Fat                    0.185570
# Hand (Length)               0.628011
# Hand (Width)                0.412774
# Bench                       0.250052
# Agility                     0.397549
# Sprint                      0.298186
# Rotation                   -0.032612
# MP                         -0.383314
# FG                         -0.241124
# FGA                        -0.445372
# FG%                         0.553690
# 2P                          0.168291
# 2PA                         0.042906
# 2P%                         0.419133
# 3P                         -0.599070
# 3PA                        -0.621811
# 3P%                        -0.379020
# FT                         -0.243474
# FTA                        -0.095418
# FT%                        -0.472417
# ORB                         0.628245
# DRB                         0.459340
# TRB                         0.569483
# AST                        -0.656861
# STL                        -0.436819
# BLK                         0.654051
# TOV                        -0.266673
# PF                          0.316248
# PTS                        -0.375135
# SOS                         0.027227
# Net TOV                    -0.072606
# BMI                         0.478911
# TS%                         0.091839
# EFG%                        0.251986
# Speed                       0.398602
# Range                       0.602129
# Scoring Impact             -0.326657
# Arm Length                  0.312089
# Adj. Scoring Impact        -0.357505
# Name: Vertical (No Step Reach), dtype: float64

# %% [markdown]
# Create list of features to perform eda on

# %%
features = ['Height (No Shoes)','Height (With Shoes)','Wingspan','Standing reach',
            'Vertical (Max)','Vertical (Max Reach)','Vertical (No Step)',
            'Vertical (No Step Reach)','Weight','Body Fat','Hand (Length)','Hand (Width)',
           'Bench','Agility','Sprint','FG','FGA','FG%','2P','2PA','2P%','3P','3PA','3P%',
           'FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','SOS',
            'Net TOV','BMI','TS%','Speed','Range','Scoring Impact','Adj. Scoring Impact',
            'EFG%','Length','Arm Length']
n = 4
row_groups= [features[i:i+n] for i in range(0, len(features), n) ]

# %% [markdown]
# Create scatter plots to represent relationship between each feature and the y variable, Rotation

# %%
for feat in features:
    pp = sns.lmplot(x=feat, y='Rotation', data=draft_df, ci=None, logistic=True)
# Out:
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-dd0f762026e0> in <module>
#       1 for feat in features:
# ----> 2     pp = sns.lmplot(x=feat, y='Rotation', data=draft_df, ci=None, logistic=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     577     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     578     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 579     data = data[cols]
#     580
#     581     # Initialize the grid
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['Length'] not in index"

# %% [markdown]
# Create scatter plots to represent relationship between each feature and the y variable, Rotation

# %%
for feat in features:
    df_temp = draft_df.groupby(feat)[feat,'Rotation'].mean()
    pp = sns.lmplot(x=feat, y='Rotation', data=df_temp, ci=None, logistic=True, x_jitter=0.05, y_jitter=0.05)
# Out:
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-a237b59a616f> in <module>
#       1 for feat in features:
# ----> 2     df_temp = draft_df.groupby(feat)[feat,'Rotation'].mean()
#       3     pp = sns.lmplot(x=feat, y='Rotation', data=df_temp, ci=None, logistic=True, x_jitter=0.05, y_jitter=0.05)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6518             squeeze=squeeze,
#    6519             observed=observed,
# -> 6520             dropna=dropna,
#    6521         )
#    6522
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'Length'

# %% [markdown]
# Calculate proportion of datapoints in positive class

# %%
nba_df['Rotation'].mean()
# Out:
# 0.2574074074074074

# %% [markdown]
# # Modeling

# %% [markdown]
# Create x and y variables with corresponding columns from draft df

# %%
x = draft_df[['Height (With Shoes)','Vertical (Max)','Body Fat','Agility','2P','FTA','STL',
             'Speed','Adj. Scoring Impact','Arm Length','PTS','SOS']]
y = draft_df['Rotation']

# %% [markdown]
# Perform train test split on x and y variables

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=12)

# %% [markdown]
# Fit Dummy Classifier model

# %%
from sklearn.dummy import DummyClassifier
dummy = DummyClassifier(random_state = 26)
dummy.fit(x_train,y_train)
# Out:
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# DummyClassifier(constant=None, random_state=26, strategy='warn')

# %% [markdown]
# Calculate Dummy Classifier evaluation metrics

# %%
from sklearn import metrics
y_pred_dummy_train = dummy.predict(x_train)
y_pred_dummy = dummy.predict(x_test)
print(metrics.precision_score(y_test, y_pred_dummy))
print(metrics.accuracy_score(y_test, y_pred_dummy))
print(metrics.f1_score(y_test, y_pred_dummy))
print(metrics.precision_score(y_train, y_pred_dummy_train))
print(metrics.accuracy_score(y_train, y_pred_dummy_train))
print(metrics.f1_score(y_train, y_pred_dummy_train))
# Out:
# 0.32142857142857145
# 0.5494505494505495
# 0.3050847457627119
# 0.23376623376623376
# 0.5888888888888889
# 0.24489795918367346

# %% [markdown]
# Create dictionary of gridsearch parameters for Random Forest model

# %%
from sklearn.model_selection import GridSearchCV
p={'max_depth': range(3,11),
   'min_samples_leaf': range(5,15,1),}

# %% [markdown]
# Create and fit gridsearch for Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
rfc = RandomForestClassifier(random_state = 23,
                             n_estimators = 100,
                             class_weight='balanced')
grid_tree=GridSearchCV(rfc,p, cv=5, scoring='precision', verbose=1,n_jobs=-1)
grid_tree.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:   44.2s finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight='balanced',
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=23,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': range(3, 11),
#                          'min_samples_leaf': range(5, 15)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='precision', verbose=1)

# %% [markdown]
# Calculate evaluation metrics for Random Forest gridsearch

# %%
from sklearn import metrics
print(grid_tree.best_score_)
print(grid_tree.best_params_)
print(grid_tree.best_estimator_)
y_pred_grid = grid_tree.best_estimator_.predict(x_test)
y_pred_grid_train = grid_tree.best_estimator_.predict(x_train)
print(metrics.precision_score(y_test, y_pred_grid))
print(metrics.accuracy_score(y_test, y_pred_grid))
print(metrics.f1_score(y_test, y_pred_grid))
print(metrics.precision_score(y_train, y_pred_grid_train))
print(metrics.accuracy_score(y_train, y_pred_grid_train))
print(metrics.f1_score(y_train, y_pred_grid_train))
# Out:
# 0.281034188034188
# {'max_depth': 3, 'min_samples_leaf': 13}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=3, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=13, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=23, verbose=0,
#                        warm_start=False)
# 0.5217391304347826
# 0.6703296703296703
# 0.4444444444444444
# 0.5263157894736842
# 0.7555555555555555
# 0.547945205479452

# %% [markdown]
# Scale x variables using standard scaler for KNN model

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_cont = ss.fit_transform(x)
x_cont = pd.DataFrame(x_cont,columns = x.columns)
x_cont
# Out:
#      Height (With Shoes)  Vertical (Max)  Body Fat   Agility        2P  \
# 0               0.974991        0.023263  0.436093 -0.686241  3.180184
# 1              -0.192024        0.454116 -0.830459 -0.313494 -0.955972
# 2              -0.581029       -0.120354 -1.116455 -0.276220  0.247274
# 3               0.819389       -0.407589  0.558663 -0.369406  1.525722
# 4               1.052792       -0.694824 -0.789603 -0.276220  0.247274
# ..                   ...             ...       ...       ...       ...
# 356            -1.359039       -0.551206 -0.095042 -0.593055  0.247274
# 357            -0.347626       -0.563980  0.476950 -0.338266 -0.053538
# 358            -1.436840        0.023263 -0.299324 -0.145758 -1.557595
# 359             0.585986       -0.438369  0.681232  0.462604  0.924099
# 360            -1.203437       -0.263971 -0.626176 -1.674021  0.322476
#
#           FTA       STL     Speed  Adj. Scoring Impact  Arm Length       PTS  \
# 0    2.811781 -0.111954 -0.467888             2.047530   -1.140872  1.728824
# 1   -0.939020  2.186546 -0.637848            -0.665040   -0.384539 -0.764078
# 2    0.229262  0.079588 -0.773815             0.480523    0.871137  0.213530
# 3    2.442850  0.079588 -0.314924             1.642285   -0.787561  1.240019
# 4   -0.570089 -0.303495  0.058987            -0.266026    0.243639 -0.348595
# ..        ...       ...       ...                  ...         ...       ...
# 356 -0.939020  0.654213 -0.768150             0.975859   -0.955006  0.189090
# 357  1.090102  0.271130 -0.414084             0.612257   -0.131532 -0.153073
# 358 -0.816043  0.845755 -0.654844            -1.337648    1.862900 -1.423964
# 359  1.213079 -0.686579  0.568621             0.451112   -0.778898  1.802144
# 360  0.044796  1.037296 -1.425327            -0.129499    0.433481  0.286851
#
#           SOS
# 0    0.015818
# 1    0.475162
# 2    0.673311
# 3    0.457149
# 4    0.475162
# ..        ...
# 356  1.534956
# 357  1.405860
# 358  0.240987
# 359 -2.527087
# 360 -0.809801
#
# [361 rows x 12 columns]

# %% [markdown]
# Perform train test split on scaled data

# %%
x_train_s, x_test_s, y_train_s, y_test_s = train_test_split(x_cont,y,random_state=15)

# %% [markdown]
# Define parameter dictionary for knn gridsearch

# %%
p={'n_neighbors': range(1,15)}

# %% [markdown]
# Create and fit KNN grid search

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
grid_tree_knn=GridSearchCV(knn,p, cv=10, scoring='precision', verbose=1)
grid_tree_knn.fit(x_train_s, y_train_s)
# Out:
# Fitting 10 folds for each of 14 candidates, totalling 140 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=1)]: Done 140 out of 140 | elapsed:    0.8s finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': range(1, 15)}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring='precision',
#              verbose=1)

# %% [markdown]
# Calculate evaluation metrics for KNN grid search

# %%
print(grid_tree_knn.best_score_)
print(grid_tree_knn.best_params_)
print(grid_tree_knn.best_estimator_)
y_pred_knn = grid_tree_knn.best_estimator_.predict(x_test_s)
y_pred_knn_train = grid_tree_knn.best_estimator_.predict(x_train_s)
print(metrics.precision_score(y_train_s, y_pred_knn_train))
print(metrics.accuracy_score(y_train_s, y_pred_knn_train))
print(metrics.f1_score(y_train_s, y_pred_knn_train))
print(metrics.precision_score(y_test_s, y_pred_knn))
print(metrics.accuracy_score(y_test_s, y_pred_knn))
print(metrics.f1_score(y_test_s, y_pred_knn))
# Out:
# 0.20906288156288158
# {'n_neighbors': 1}
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')
# 0.9722222222222222
# 0.9851851851851852
# 0.9722222222222222
# 0.37142857142857144
# 0.5824175824175825
# 0.40625

# %% [markdown]
# Create and fit logistic regression model

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x_train_s, y_train_s)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Calculate evaluation metrics for logistic regression model

# %%
y_pred_log = logreg.predict(x_test_s)
y_pred_log_train = logreg.predict(x_train_s)
print(metrics.precision_score(y_train_s, y_pred_log_train))
print(metrics.accuracy_score(y_train_s, y_pred_log_train))
print(metrics.f1_score(y_train_s, y_pred_log_train))
print(metrics.precision_score(y_test_s, y_pred_log))
print(metrics.accuracy_score(y_test_s, y_pred_log))
print(metrics.f1_score(y_test_s, y_pred_log))
# Out:
# 0.3125
# 0.7111111111111111
# 0.11363636363636365
# 0.45454545454545453
# 0.6703296703296703
# 0.25000000000000006

# %% [markdown]
# Determine coefficients for logistic regression model

# %%
coef = zip(x_train.columns, logreg.coef_[0])

# %%
list(coef)
# Out:
# [('Height (With Shoes)', 0.2775015632003029),
#  ('Vertical (Max)', -0.1333632268156084),
#  ('Body Fat', -0.2506451424695124),
#  ('Agility', -0.5427109079031481),
#  ('2P', 0.4891914741810154),
#  ('FTA', 0.20121912337206455),
#  ('STL', 0.4759896425165689),
#  ('Speed', 0.0607093245593565),
#  ('Adj. Scoring Impact', 0.2936044745563431),
#  ('Arm Length', -0.020566020285063248),
#  ('PTS', -0.47885991191092625),
#  ('SOS', 0.152479357695926)]

# %%
x_train.columns
# Out:
# Index(['Height (With Shoes)', 'Vertical (Max)', 'Body Fat', 'Agility', '2P',
#        'FTA', 'STL', 'Speed', 'Adj. Scoring Impact', 'Arm Length', 'PTS',
#        'SOS'],
#       dtype='object')
